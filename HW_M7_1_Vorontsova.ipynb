# %% [markdown]
# У завданнях 1-4. Вам наданий простий код на Python, який не відповідає вказівкам PEP8. Ваше завдання — відредагувати код так, аби він відповідав PEP8. Напишіть після редагуванню коду, дотримання яких правил з pep8 ви досягли в відредагованій версі, наприклад
# ```
# - додала пробіли навколо бінарного оператора
# - додала два порожні рядки між визначеннями функцій
# і тд
# ```
# Також можна зазанчити використані правила коментарями по коду, а не окремим повідомленням.
#
# Відредагований код має виконувати весь той самий функціонал, але бути написаний відповідно до вимог до гарного коду на Python! Не забудьте запустити відредагований код, він має бути робочим.

# %% [markdown]
# Завдання 1.

# %%
def greet(name):print(f"Hello, {name}")
def add(n1,n2):return n1+n2

x = 5;y = 3
display(greet("John"),add(x,y))
# Out:
# Hello, John
# None
# 8

# %%
def print_greet(name):             # вказала більш чіткішу назву функції та додала відповідні абзаци по тілу функції замість функції в один рядок
    """ 
    Print greeting for indicated person`s name.
    :param name: Indicated person`s name.
    :return: None.
    """                            # додала docstrings
    print(f"Hello, {name}")
                                   # додала абзац для розділення функцій
def add_numbers(number1, number2): # вказала більш чіткішу назву функції та змінні, додала відповідні абзаци по тілу функції замість функції в один рядок
    """
    Adds two numbers together.
    :param number1: The first number.
    :param number2: The second number.
    :return: The sum of the two numbers.
    """                            # додала docstrings
    return number1 + number2

x, y = 5, 3                        # змінила формат введення 2-х змінних для більш лаконічної та стильнішої подачі
display(print_greet("John"),add_numbers(x,y))
# Out:
# Hello, John
# None
# 8

# %% [markdown]
# Завдання 2.

# %%
from math import *
def calcArea(r):return pi*r**2
def calcCircumference(r):return 2*pi*r

radius=5
print("Area:",calcArea(radius),"Circumference:",calcCircumference(radius))
# Out:
# Area: 78.53981633974483 Circumference: 31.41592653589793

# %%
import math                             # змінила запис на рекомендований формат
                                        # додала абзац для розділення блоку імпорту бібліотек та решти коду
def calc_area(radius):                  # вказала правильну назву функції (lower_case) та більш зрозумілу назву змінної, додала відповідні абзаци по тілу функції замість функції в один рядок
    """
    Calculate area by indicated radius.
    :param radius: Indicated radius.
    :return: Area by indicated radius.
    """                                 # додала docstrings
    return pi * radius**2               # додала необхідні пробіли між змінними та операторами
                                        # додала абзац для розділення функцій
def calc_circumference(radius):         # вказала правильну назву функції (lower_case) та більш зрозумілу назву змінної, додала відповідні абзаци по тілу функції замість функції в один рядок
    """
    Calculate circumference by indicated radius.
    :param radius: Indicated radius.
    :return: Circumference by indicated radius.
    """                                 # додала docstrings
    return 2 * pi * radius              # додала необхідні пробіли між змінними та операторами

radius = 5                              # додала необхідні пробіли між змінною та знаком присвоєння (=)
print("Area:", calc_area(radius),       # для зручності читання коду додала абзац між викликами 2-х фукнцій, не впливає на вивід
      "Circumference:", calc_circumference(radius))
# Out:
# Area: 78.53981633974483 Circumference: 31.41592653589793

# %% [markdown]
# Завдання 3.

# %%
class animal: pass
class dog(animal):
    def __init__(self,name):
        self.name=name
        self.type='Dog'

# %%
class Animal:                                                 # вказала правильну назву класу (згідно CapWords), додала відповідні абзаци далі по тілу коду
    """Base class for animals."""                             # додала docstrings
    pass
                                                              # додала абзац для розділення блоків коду та структурування
class Dog(Animal):                                            # вказала правильну назву класу (згідно CapWords), додала відповідні абзаци далі по тілу коду
    """Class for dogs, inheriting from the Animal class."""   # додала docstrings
                                                              # додала абзац для легкості читання    
    def __init__(self, name):                                 # додала пробіл між змінними
        """Initializes a Dog object.
        :param name: The dog`s name.
        """                                                   # додала docstrings
        self.name = name                                      # додала потрібні пробіли між знаком = (присвоєння)
        self.type = 'Dog'                                     # додала потрібні пробіли між знаком = (присвоєння)

# %% [markdown]
# Завдання 4.

# %%
list=[1,2,3,4,5]
for i in range(len(list)):print(list[i])
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
my_list = [1,2,3,4,5]  # змінила назву списку на більш коректну з точки зору уникнення конструкцій python, доала пробіли між пробіли між знаком = (присвоєння)
                       # додала абзац для читабельності і структурування коду
for item in my_list:   # змінила назву змінної на більш коректну та стисліше і чіткіше переписала сам код, додала абзац після знаку :
    print(item)
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# 5.У вас є DataFrame df, що представляє результати тестів студентів з математики, англійської мови та історії. Поточний код обчислює середній бал для кожного студента шляхом ітерації за рядками DataFrame за допомогою iterrows().
#
# Ваше завдання полягає в тому, щоб змінити код так, аби уникнути використання iterrows() і замість цього застосувати більш ефективне та читабельне рішення відповідно до правил, озвучених у лекції. Рефакторинг треба зробити лише частині, де рахуються середні, імпорт і визначення датафрейму лишаємо без змін.

# %%
import pandas as pd

df = pd.DataFrame({
    'student': ['Alice', 'Bob', 'Charlie', 'David'],
    'math_score': [89, 94, 77, 85],
    'english_score': [92, 88, 79, 85],
    'history_score': [84, 92, 81, 89]
})

# %%
# old version
averages = []
for _, row in df.iterrows():
    averages.append((row['math_score'] + row['english_score'] + row['history_score']) / 3)

df['average_score'] = averages

# %%
# update version
df_with_avgscore = df.copy()                                                   # модифікую не основний датасет, а створюю нову версію з доповненням
df_with_avgscore['average_score'] = df_with_avgscore.iloc[:, 1:].mean(axis=1)  # використовую вбудовану функцію та прибираю цикл
df_with_avgscore
# Out:
#    student  math_score  english_score  history_score  average_score
# 0    Alice          89             92             84      88.333333
# 1      Bob          94             88             92      91.333333
# 2  Charlie          77             79             81      79.000000
# 3    David          85             85             89      86.333333

# %% [markdown]
# 6.У Вас є великий DataFrame df, що представляє транзакції продажу в магазині. Цей DataFrame містить понад 1 мільйон рядків і кілька стовпців, зокрема «product_name», «product_category», «product_price» і «transaction_date».
#
# І «product_name», і «product_category» є рядками, що представляють численні, але обмежені унікальні назви продуктів і категорії відповідно.
#
# Напишіть код для ефективного перетворення стовпців «product_name» і «product_category» на категорійний тип для ефективного використання пам’яті.
# Спробуйте вирішити це завдання, мінімізуючи використання пам'яті та зберігаючи читабельність коду. Крім того, виміряйте використання пам’яті до та після перетворення, щоб продемонструвати підвищення ефективності.
#
# Порівняйте кількість памʼяті, яку займає наданий набір даних і новий, створений Вами. В лекції був приклад. В скільки разів менше памʼяті займає новий датафрейм?

# %%
# old version
import pandas as pd
import numpy as np

np.random.seed(0)

products = ['apple', 'banana', 'cherry', 'dates', 'elderberry']
categories = ['fruit', 'fruit', 'fruit', 'fruit', 'fruit']

N_ROWS = 10**6
df = pd.DataFrame({
    'product_name': np.random.choice(products, N_ROWS),
    'product_category': np.random.choice(categories, N_ROWS),
    'product_price': np.random.uniform(1, 10, N_ROWS),
    'transaction_date': pd.date_range(start='1/1/2000', periods=N_ROWS, freq='h')
})

df_size = df.memory_usage(index=False).sum()
df_size
# Out:
# 32000000

# %%
# update version
import pandas as pd
import numpy as np

np.random.seed(0)

PRODUCTS = ['apple', 'banana', 'cherry', 'dates', 'elderberry']
CATEGORIES = ['fruit', 'fruit', 'fruit', 'fruit', 'fruit']
N_ROWS = 10**6

df2 = pd.DataFrame({
    'product_name': pd.Categorical(np.random.choice(PRODUCTS, N_ROWS)),
    'product_category': pd.Categorical(np.random.choice(CATEGORIES, N_ROWS)),
    'product_price': np.random.uniform(1, 10, N_ROWS),
    'transaction_date': pd.date_range(start='1/1/2000', periods=N_ROWS, freq='h'),
})

df2_size = df2.memory_usage(index=False).sum()
df2_size
# Out:
# 18000328

# %%
print(f"Відповідь: маємо зниження витрат памʼяті на {round((1-df2_size/df_size)*100,2)}% !")
# Out:
# Відповідь: маємо зниження витрат памʼяті на 43.75% !

# %% [markdown]
# 7.В цьому завданні кілька пунктів. Треба виконати усі послідовно.
#     7.1. Завантажте дані у pandas dataframe з файла `ecommerce_data.csv`. Обовʼязково при завантаженні вкажіть параметр `encoding = 'ISO-8859-1'`, без нього буде помилка.
#     7.2. Заповніть пропущені значення в колонці CustomerID на -1 та перетворіть тип цієї колонки на str, адже зараз вона типу float, а це не правильний тип даних для ідентифікатора клієнта.
#     7.3. З допомогою бібліотеки sweetviz побудуйте html звіт, який порівнює дані для країни "Germany" і країни "France". У Вас можуть виникнути багато попереджень (Warning), їх рекомендую вимкнути наступним шматком коду
#
#
#     import warnings
#
#     with warnings.catch_warnings(record=True):
#         # your code
#
#
#    7.4.Напишіть 5 відмінностей для двох зазначених країн на основі побудованого звіту, без виконання додаткового аналізу іншими інструментами.

# %%
import pandas as pd

# %%
data_path = '../M7/ecommerce_data.csv'
df = pd.read_csv(data_path, encoding = 'ISO-8859-1')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
df_upd = df.copy()
df_upd.CustomerID = df_upd.CustomerID.fillna(-1).astype(str)

# %%
! pip install sweetviz

# %%
import sweetviz as sv

# %%
import warnings

with warnings.catch_warnings(record=True):
    compare_report = sv.compare(
    [df_upd[df.Country == 'Germany'], "Germany"],
    [df_upd[df.Country == 'France'], "France"])
compare_report.show_html('sweet_compare_report.html')
# Out:
#                                              |                                             | [  0%]   00:00 ->…
# Report sweet_compare_report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %% [markdown]
# Висновки:
#
# 1. У Німеччини датасет складає 9495 рядків даних, у Франції - 8557 рядків.
# 2. Максимальна кількість в замовленні (Quantity) для Франції склала 912 од., для Німеччини - 600 од.
# 3. Середня к-сть в замовленні (Quantity) також відмінна і складає 13 од. для Франції та 12 од. для Німеччини відповідно. При цьому значення медіани співпадає і становить на рівні 10 од.
# 4. Максимальна ціна замовлення (UnitPrice) у датасеті Франції склала 4161 од., у Німеччині - 600 од.
# 5. Середня ціна замовлення (UnitPrice) також варіюється і складає 5 од. для Франції та 4 од. для Німеччини відповідно. При цьому значення медіани співпадає і становить на рівні 2 од.
# 6. По типам Description	значимих відмінностей не виявлено.

# %% [markdown]
# 8.З допомогою ChatGPT виявіть, чи є та які помилки в наступному коді.
# Попросіть після цього переписати код із дотриманням PEP8. Проаналізуйте результат. Чи справді ChatGPT виправив всі стилістичні помилки? Якщо ні, напишіть йому ще кілька запитів, аби код відповідав вимогам PEP8.
# Вставте фінальну версію коду з чату у ноутбук та запустіть на заданому списку. Має вертатись 50.
# Напишіть, які промпти (інструкції) при зверненні до ChatGPT ви застосували та додайте скріншот(-и) з промптами та відповідями чата.
# Якщо зробили висновки при виконанні цього завдання, то діліться також :)
#
# **ЯК ВСТАВИТИ СКРІНШОТ в Jupyter Notebook** :
# 1. Створіть нову Markdown клітинку
# 2. В новоствореній клітинці обираєте в меню Jupyter Notebook Edit -> Insert Image
# 3. Обираєте картинку
# 4. В клітинці має зʼявитись текст, який містить картинку. Запустіть клітинку.
#
# Або можна просто перетягнути картинку в Markdown клітинку.

# %%
def CalculateVariance(nl):
    sum_list = 0
    for n in nl:
        sum_list = sum_list + n
    mean = sum_list / len(nl)
    sum_squares = 0
    for n in nl:
        sum_squares = sum_squares + n**2
    mean_squares = sum_squares / len(nl)
    return mean_squares

# %%
input_list = [75, 80, 85, 90, 95]
CalculateVariance(input_list)
# Out:
# 7275.0

# %%
def calculate_variance(numbers):
    """Calculates the variance of a list of numbers.
    
    Args:
        numbers (list of float or int): A list of numerical values.
    
    Returns:
        float: The variance of the given numbers.
    """
    mean = sum(numbers) / len(numbers)
    return sum((n - mean) ** 2 for n in numbers) / len(numbers)

# %%
input_list = [75, 80, 85, 90, 95]
calculate_variance(input_list)
# Out:
# 50.0

# %% [markdown]
# ![image1.jpg](attachment:image1.jpg)

# %% [markdown]
# ![image2.jpg](attachment:image2.jpg)

# %% [markdown]
# ![image3.jpg](attachment:image3.jpg)

# %% [markdown]
# ![image4.jpg](attachment:image4.jpg)

# %% [markdown]
# ![image5.jpg](attachment:image5.jpg)

# %% [markdown]
# ![image6.jpg](attachment:image6.jpg)

# %% [markdown]
# Висновок: chatGPT дуже гарний помічний у пошуку помилок в коді, оптимізації чи покращенні коду. Гарно розуміє побажання і реалізує їх в коді. Однак це більше як помічник, а не замінник. Самостійно переглядати та перепровіряти потрібно завжди.
#
# Також додам, що мені сподобалася пропозиція чату по виправленню коду і я залишила її, однак дану задачу можна було також вирішити і через вбудовані статистичні функції (як альтернативний варіант).
